# %%
"""                  #LINEAR REGRESSION    [next op predict krne ke liye]
from sklearn.linear_model import LinearRegression 

x=[[1],[2],[3],[4],[5]]
y=[[23],[34],[45],[56],[67]]
model=LinearRegression().fit(x,y)
hours=float(input())
b=model.predict([[hours]])
print(b[0][0])    #answer 2d me aa rha tha thats why uske andr access kra


              #logistic Regression

from sklearn.linear_model import LogisticRegression 

x=[[1],[2],[3],[4],[5]]
y=[0,0,1,1,1]                   #they are class labels,not contigous numbers, thats why in 1d format
model=LogisticRegression()
model.fit(x,y)
hours=float(input())
b=model.predict([[hours]])
if b==1:
    print("pass")
else:
    print("Fail")


                 #KNN
from sklearn.neighbors import KNeighborsClassifier
x= [[56,7],
   [67,8],
   [76,9],
   [90,10],
   [99,11]]
y=[0,1,0,1,0,]
model=KNeighborsClassifier(n_neighbors=3)
model.fit(x,y)
weight=int(input())
size=float(input())
b=model.predict([[weight,size]])
if b==1:
    print("t")
else:
    print("f")
"""   

                #Accuracy,precision,recall,F1score. mean_Absolute,squared,root
"""
from sklearn.metrics  import accuracy_score,precision_score,recall_score, f1_score
y_true=[1,1,0,0,1,1]
y_predict=[1,1,1,0,0,0]
print(accuracy_score(y_true,y_predict))
print(precision_score(y_true,y_predict))
print(recall_score(y_true,y_predict))
print(f1_score(y_true,y_predict))

from sklearn.metrics import confusion_matrix
y=[1,1,1,0,0,0,1,1,1]
x=[1,0,1,1,1,1,0,1,1]

b=confusion_matrix(y,x)       #wahi acual/predicted[True,false] wali table
print("Confusion matrix")
print(b)
"""

from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
actual=[90,56,78,80,13]
pred=[85,62,75,80,16]

absolute=mean_absolute_error(actual,pred)
squared=mean_squared_error(actual,pred)
root=np.sqrt(squared)

print(absolute)
print(squared)
print(root)
# Out:
# 3.4
# 15.8
# 3.9749213828703582
